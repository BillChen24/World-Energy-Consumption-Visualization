# %%
import pandas as pd
import numpy as np

# %%
consumption_data = pd.read_csv("https://drive.google.com/uc?id=1D9mWQJlp6n8eF7zr0hdTB1T03MWRXTWz")

# %%
consumption_data.head(5)
# Out:
#   iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0      AFG  Afghanistan  1900                   NaN                   NaN
# 1      AFG  Afghanistan  1901                   NaN                   0.0
# 2      AFG  Afghanistan  1902                   NaN                   0.0
# 3      AFG  Afghanistan  1903                   NaN                   0.0
# 4      AFG  Afghanistan  1904                   NaN                   0.0
#
#    gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    oil_prod_change_twh  energy_cons_change_pct  ...  solar_elec_per_capita  \
# ...

# %%
cs = consumption_data[(consumption_data['country'].isin(['China', 'Japan', 'United States', 'South Africa', 'Mexico', 'United Kingdom'])) & (consumption_data['year'] >= 1980) & (consumption_data['year'] <= 2019)]
cols = [
     'country',
     'year',
     'coal_consumption',
     'coal_cons_per_capita',
     'fossil_fuel_consumption',
     'fossil_cons_per_capita',
     'gas_consumption',
     'gas_energy_per_capita',
     'hydro_consumption',
     'hydro_energy_per_capita',
     'nuclear_consumption',
     'nuclear_energy_per_capita',
     'oil_consumption',
     'oil_energy_per_capita',
     'primary_energy_consumption',
     'electricity_generation',
     'per_capita_electricity',
     'renewables_consumption',
     'renewables_energy_per_capita',
     'primary_energy_consumption',
     'energy_per_capita']
cs_wcols = cs[cols]

# %%
cs_wcols = cs_wcols.fillna(0)

# %%
cs_wcols.to_csv('data.csv')
